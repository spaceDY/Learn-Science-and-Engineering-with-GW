# %% [markdown]
# # Acceleration of a falling ball

# %%
from IPython.display import YouTubeVideo
vid = YouTubeVideo("xQ4znShlK5A")
display(vid)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=xQ4znShlK5A"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import imageio
import numpy
from matplotlib import pyplot

# %%
reader = imageio.get_reader('https://go.gwu.edu/engcomp3vidmit', format='mp4')

# %%
type(reader)
# Out:
# imageio.plugins.ffmpeg.FfmpegFormat.Reader

# %%
len(reader)
# Out:
# 9223372036854775807

# %%
fps = reader.get_meta_data()['fps']
print(fps)
# Out:
# 29.97

# %% [markdown]
# ## Get a frame from the video

# %%
# %matplotlib notebook

pyplot.rc('font', family='serif', size='18')

# %%
image = reader.get_data(1100)
image.shape
# Out:
# (1080, 1440, 3)

# %%
type(image)
# Out:
# imageio.core.util.Array

# %% [markdown]
# ## Interactive figure

# %%
pyplot.imshow(image, interpolation='nearest');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Capture mouse clicks

# %%
def onclick(event):
    '''Capture the x,y coordinates of a mouse click on the image'''
    ix, iy = event.xdata, event.ydata
    coords.append([ix, iy])

# %%
fig = pyplot.figure()
pyplot.imshow(image, interpolation='nearest')

coords = []
connectId = fig.canvas.mpl_connect('button_press_event', onclick)
# Out:
# <img src="data:image/png;base64,..." width="640">
